# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(26918.223740919864)

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# np.float64(26814.49561389107)

# %% [markdown]
# Now we'll add Donald Trump into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# np.float64(26815.274381164436)

# %%
np.mean(incomes)
# Out:
# np.float64(126905.53318760109)

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([68, 66, 62, 45, 73, 84, 39, 77, 86, 62, 85, 58, 22, 43, 67, 76, 19,
#        38, 60, 33, 47, 35, 84, 26, 44, 32, 67, 38, 66, 58, 69, 62, 63, 82,
#        32, 45, 73, 64, 50, 81, 77, 70, 82, 62, 50, 56, 41, 26, 33, 58, 47,
#        54, 31, 35, 77, 67, 51, 89, 48, 59, 77, 33, 44, 80, 79, 54, 83, 38,
#        19, 73, 71, 68, 62, 19, 79, 65, 47, 51, 76, 83, 18, 50, 31, 39, 20,
#        67, 48, 75, 55, 21, 28, 83, 19, 18, 27, 28, 61, 27, 21, 24, 45, 44,
#        69, 28, 89, 25, 49, 66, 32, 52, 24, 70, 45, 50, 63, 84, 87, 80, 20,
#        75, 34, 61, 44, 27, 54, 81, 89, 25, 56, 85, 35, 26, 32, 25, 38, 62,
#        59, 38, 30, 29, 41, 50, 53, 53, 69, 35, 19, 64, 42, 28, 75, 64, 75,
#        81, 63, 28, 40, 82, 25, 41, 84, 20, 47, 18, 61, 57, 22, 47, 76, 30,
#        75, 24, 76, 65, 35, 73, 29, 28, 47, 80, 32, 88, 59, 51, 79, 78, 59,
#        41, 26, 84, 33, 19, 80, 64, 42, 55, 24, 28, 42, 49, 50, 85, 21, 34,
#        58, 35, 63, 32, 47, 47, 66, 69, 41, 55, 29, 47, 76, 33, 30, 73, 30,
#        51, 47, 27, 74, 65, 81, 61, 30, 57, 39, 45, 29, 61, 53, 33, 47, 44,
#        56, 38, 19, 80, 23, 29, 50, 68, 87, 39, 59, 87, 44, 69, 78, 74, 83,
#        61, 41, 19, 29, 66, 40, 74, 56, 19, 38, 46, 57, 40, 57, 38, 19, 71,
#        28, 20, 37, 42, 21, 52, 62, 32, 79, 51, 55, 25, 81, 59, 29, 81, 66,
#        65, 25, 41, 86, 23, 22, 53, 64, 56, 44, 60, 28, 74, 54, 31, 45, 83,
#        66, 46, 44, 43, 89, 31, 86, 82, 76, 43, 47, 22, 50, 70, 38, 68, 72,
#        38, 20, 81, 58, 73, 34, 67, 57, 76, 23, 86, 32, 89, 33, 81, 50, 53,
#        35, 73, 23, 70, 72, 55, 89, 82, 25, 45, 38, 63, 56, 59, 72, 57, 61,
#        49, 73, 22, 44, 44, 50, 23, 68, 61, 36, 23, 36, 26, 36, 58, 25, 23,
#        53, 40, 43, 56, 19, 52, 56, 66, 36, 41, 85, 69, 31, 39, 24, 71, 22,
#        74, 47, 83, 44, 71, 46, 54, 78, 83, 24, 19, 76, 61, 60, 43, 58, 27,
#        50, 34, 43, 23, 61, 33, 40, 43, 36, 76, 42, 19, 82, 74, 23, 31, 57,
#        35, 18, 85, 35, 88, 59, 34, 55, 69, 81, 46, 58, 84, 31, 70, 72, 68,
#        87, 76, 61, 23, 57, 89, 54, 24, 74, 66, 84, 19, 30, 24, 57, 62, 41,
#        34, 70, 19, 30, 89, 54, 64, 43, 41, 76, 77, 29, 81, 49, 73, 78, 63,
#        32, 66, 70, 40, 78, 27, 26, 21, 80, 73, 83, 70, 71, 42, 61, 86, 65,
#        65, 73, 74, 29, 27, 37, 34])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(19), count=np.int64(15))
