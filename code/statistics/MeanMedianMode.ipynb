# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(27331.46198654032)

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# np.float64(27445.78521914307)

# %% [markdown]
# Now we'll add Donald Trump into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# np.float64(27446.153740175312)

# %%
np.mean(incomes)
# Out:
# np.float64(127318.73011352895)

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([64, 41, 20, 44, 70, 51, 47, 53, 27, 69, 80, 89, 78, 25, 75, 31, 62,
#        26, 22, 19, 26, 49, 37, 58, 86, 54, 44, 29, 33, 25, 89, 18, 38, 44,
#        23, 18, 55, 58, 54, 83, 57, 88, 48, 77, 81, 51, 27, 34, 30, 77, 58,
#        47, 18, 84, 42, 34, 69, 34, 65, 89, 62, 24, 36, 82, 78, 70, 20, 78,
#        67, 79, 24, 36, 52, 76, 51, 51, 45, 74, 62, 28, 24, 30, 40, 21, 56,
#        56, 39, 80, 73, 85, 84, 62, 53, 20, 71, 36, 38, 53, 39, 47, 34, 79,
#        71, 27, 18, 23, 27, 27, 43, 34, 52, 42, 49, 77, 56, 37, 18, 69, 48,
#        47, 40, 38, 54, 27, 70, 48, 39, 40, 19, 67, 51, 47, 68, 31, 30, 53,
#        89, 85, 79, 36, 28, 57, 46, 27, 46, 82, 58, 80, 19, 57, 27, 69, 80,
#        68, 53, 28, 45, 43, 30, 30, 42, 43, 25, 34, 68, 55, 45, 68, 40, 70,
#        52, 35, 55, 53, 25, 66, 27, 69, 60, 72, 40, 89, 57, 87, 25, 38, 49,
#        20, 33, 25, 57, 25, 70, 42, 51, 19, 64, 25, 39, 60, 20, 67, 79, 49,
#        74, 86, 20, 52, 72, 34, 76, 68, 24, 39, 53, 37, 22, 53, 29, 47, 75,
#        21, 75, 88, 56, 27, 32, 49, 58, 38, 89, 23, 75, 53, 31, 42, 41, 28,
#        44, 76, 77, 24, 74, 30, 81, 63, 66, 50, 64, 69, 66, 85, 86, 72, 28,
#        48, 39, 53, 56, 39, 52, 57, 44, 85, 89, 89, 44, 63, 50, 59, 68, 43,
#        59, 65, 60, 53, 86, 64, 23, 41, 77, 77, 82, 31, 22, 42, 70, 49, 47,
#        66, 63, 34, 75, 57, 30, 43, 48, 82, 25, 71, 64, 58, 80, 35, 55, 33,
#        89, 64, 58, 79, 88, 37, 61, 68, 80, 40, 53, 26, 74, 59, 33, 43, 77,
#        50, 65, 63, 53, 36, 81, 81, 86, 66, 52, 83, 50, 43, 18, 76, 51, 24,
#        44, 25, 36, 74, 72, 23, 41, 28, 51, 88, 30, 20, 45, 54, 80, 84, 52,
#        71, 22, 64, 44, 67, 87, 43, 68, 22, 37, 24, 82, 68, 35, 55, 76, 71,
#        68, 74, 23, 85, 53, 51, 38, 44, 34, 46, 27, 19, 84, 83, 37, 39, 22,
#        80, 60, 67, 45, 83, 64, 38, 80, 70, 69, 78, 42, 18, 68, 23, 58, 83,
#        62, 28, 59, 57, 84, 87, 22, 67, 88, 27, 84, 19, 23, 33, 65, 57, 83,
#        38, 34, 61, 41, 64, 79, 49, 78, 88, 53, 36, 42, 75, 53, 44, 39, 35,
#        68, 26, 46, 38, 85, 54, 88, 75, 69, 24, 55, 66, 58, 49, 35, 79, 54,
#        30, 84, 72, 86, 43, 73, 31, 33, 35, 69, 44, 44, 22, 30, 60, 48, 33,
#        47, 46, 18, 46, 83, 27, 51, 57, 39, 47, 78, 22, 47, 75, 41, 78, 33,
#        81, 75, 84, 89, 67, 49, 68])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(53), count=np.int64(16))
