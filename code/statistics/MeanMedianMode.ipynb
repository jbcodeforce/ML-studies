# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(27022.682774172856)

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# np.float64(27116.399332561807)

# %% [markdown]
# Now we'll add Donald Trump into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# np.float64(27117.433249512073)

# %%
np.mean(incomes)
# Out:
# np.float64(127009.98177599529)

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(18, high=90, size=500)
ages
# Out:
# array([47, 54, 40, 67, 80, 42, 20, 47, 53, 55, 59, 85, 55, 40, 87, 87, 41,
#        22, 72, 79, 74, 51, 46, 81, 44, 73, 75, 56, 31, 20, 58, 40, 34, 38,
#        18, 50, 45, 61, 28, 24, 29, 58, 84, 25, 34, 52, 88, 65, 48, 89, 36,
#        27, 45, 32, 85, 24, 47, 70, 73, 70, 82, 46, 71, 76, 89, 42, 56, 62,
#        88, 53, 18, 33, 32, 60, 43, 18, 25, 28, 83, 44, 84, 83, 44, 66, 59,
#        19, 70, 35, 38, 57, 19, 47, 63, 65, 30, 54, 26, 54, 22, 46, 51, 47,
#        80, 74, 25, 60, 31, 35, 41, 70, 20, 70, 74, 80, 35, 65, 32, 88, 87,
#        76, 45, 87, 37, 61, 20, 45, 22, 89, 43, 48, 30, 39, 64, 69, 61, 65,
#        41, 59, 28, 39, 42, 70, 88, 26, 32, 69, 40, 46, 47, 58, 20, 43, 47,
#        67, 57, 44, 28, 56, 60, 88, 33, 59, 55, 25, 63, 19, 55, 55, 45, 20,
#        39, 48, 78, 42, 40, 40, 26, 69, 53, 86, 30, 33, 62, 49, 28, 34, 25,
#        56, 38, 30, 79, 62, 23, 25, 87, 58, 30, 42, 59, 48, 44, 88, 67, 72,
#        77, 46, 55, 42, 23, 35, 62, 83, 45, 69, 23, 41, 75, 29, 44, 43, 40,
#        41, 23, 65, 83, 35, 44, 37, 89, 68, 60, 34, 82, 48, 60, 51, 57, 54,
#        41, 65, 88, 39, 86, 50, 20, 74, 53, 53, 23, 31, 41, 43, 57, 48, 55,
#        89, 71, 63, 40, 31, 58, 23, 52, 67, 36, 61, 27, 44, 20, 20, 77, 43,
#        51, 56, 20, 57, 24, 73, 69, 63, 66, 58, 28, 76, 35, 18, 68, 55, 57,
#        28, 34, 68, 77, 44, 35, 69, 67, 60, 59, 84, 63, 73, 22, 77, 57, 84,
#        39, 46, 24, 36, 28, 43, 22, 29, 37, 49, 65, 67, 36, 70, 82, 66, 45,
#        33, 83, 20, 64, 24, 45, 53, 50, 88, 20, 57, 59, 50, 41, 60, 45, 74,
#        50, 24, 80, 41, 73, 82, 23, 51, 29, 56, 29, 59, 47, 34, 89, 58, 25,
#        79, 88, 82, 75, 29, 46, 42, 65, 81, 66, 56, 40, 51, 58, 42, 81, 32,
#        89, 59, 31, 38, 54, 59, 52, 26, 25, 26, 67, 73, 68, 61, 53, 85, 45,
#        80, 24, 56, 29, 22, 29, 55, 79, 18, 35, 22, 45, 81, 31, 74, 58, 57,
#        79, 86, 66, 78, 51, 19, 73, 83, 59, 48, 75, 45, 76, 31, 39, 38, 52,
#        36, 86, 38, 27, 61, 64, 66, 47, 53, 28, 41, 20, 65, 84, 31, 21, 42,
#        74, 27, 85, 43, 50, 40, 27, 66, 19, 31, 74, 64, 64, 41, 49, 78, 24,
#        59, 66, 27, 62, 62, 55, 74, 62, 22, 54, 19, 82, 73, 61, 79, 49, 87,
#        76, 41, 29, 62, 27, 83, 32, 52, 60, 70, 77, 19, 36, 71, 19, 58, 34,
#        47, 51, 60, 76, 32, 66, 61])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int64(20), count=np.int64(13))
